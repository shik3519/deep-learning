# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import torch.nn as nn
from torchvision import transforms
from torch.autograd import Variable
import torchvision.datasets as dataset

from torch.optim import lr_scheduler
from IPython.core.debugger import set_trace
import matplotlib.pyplot as plt
from PIL import Image

import os
import numpy as np
import pandas as pd
import math
from pdb import set_trace
import shutil

import bcolz
import time
from utils import *

# %%
import torch.optim as optim
from torchvision import datasets, models, transforms,utils
import time
import copy
plt.ion()   # interactive mode

# %% [markdown]
# ### Sample

# %%
path = 'data/montgomery_china_resized/'

# %%
sample = plt.imread(f'{path}train/normal/CHNCXR_0001_0.png')

# %%
plt.imshow(sample)

# %%
sample.shape #input images are of size ~300
# Out:
# (291, 300, 3)

# %% [markdown]
# ### Data pre-processing

# %%
sz =224 #we chose 224 as VGG-16 needs that size as input to the network

# %%
batch_size = 64

# %% [markdown]
# #### Defining transforms

# %%
#train transform
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(sz, scale=(1,1)),
    transforms.RandomRotation(1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) #normalization as same as Imagenet
])

#validation transform
transform_valid = transforms.Compose([
    transforms.RandomResizedCrop(sz, scale=(1,1)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %% [markdown]
# #### Dataloader

# %%
#training dataloader
traindir ='data/montgomery_china_resized/train/'
train = dataset.ImageFolder(traindir, transform_train)
train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True, num_workers=6)

# %%
#for validation
valdir ='data/montgomery_china_resized/valid/'
valid = dataset.ImageFolder(valdir, transform_valid)
valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False, num_workers=6)

# %%
dset_sizes = {'train': len(train.imgs), 'valid': len(valid.imgs)}
classes = train.classes

use_gpu = torch.cuda.is_available()

# %%
use_gpu #true if gpu is available
# Out:
# True

# %%
classes #condition indicates that x-ray has some signs of lung disease
# Out:
# ['condition', 'normal']

# %%
dset_sizes #680 training images and 120 validation images
# Out:
# {'train': 680, 'valid': 120}

# %% [markdown]
# #### Testing the dataloader

# %%
xmb,ymb = next(iter(train_loader))

# %%
xmb.shape,ymb.shape
# Out:
# (torch.Size([64, 3, 224, 224]), torch.Size([64]))

# %%
xmb,ymb = next(iter(valid_loader))

# %%
xmb.shape,ymb.shape
# Out:
# (torch.Size([64, 3, 224, 224]), torch.Size([64]))

# %% [markdown]
# ### VGG model

# %% [markdown]
# #### Downloading the model

# %%
model_vgg = models.vgg16(pretrained=True) #we are using VGG-16 model: this will download the weights for the model

# %%
model_vgg #this is how the architecture looks like
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d (3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (5): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (10): Conv2d (128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (17): Conv2d (256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (24): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000)
#   )
# )

# %% [markdown]
# Now we have a pre-trained VGG network. VGG consist of 2 logical blocks: Convolution block and then Fully connected block. Now the idea of transfer learning is generally to train the last few layers to fine tune the model to capture the complex features and output the desired number of classes. As VGG-16 model was pre-trained on Imagenet competition which needs to output probabilities for 1000 classes, we need to modify the last layer so that it outputs 2 classes: 'normal', 'condition'. Let's try that...

# %% [markdown]
# #### Replacing the classifier layer completely and modifying the last layer

# %% [markdown]
# First we'll set the gradients for all the layers to be False to freeze them so that they become non trainable

# %%
for param in model_vgg.parameters():
    param.requires_grad = False #freezing the whole network, requires_grad = False makes the layers non-learnable

# %% [markdown]
# Let's look at the classifier section of the network

# %%
model_vgg.classifier #this is the FC block of the architecture
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096)
#   (1): ReLU(inplace)
#   (2): Dropout(p=0.5)
#   (3): Linear(in_features=4096, out_features=4096)
#   (4): ReLU(inplace)
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=4096, out_features=1000)
# )

# %% [markdown]
# Copying the same layers with the last layer outputting 2 activations. Also as we are dropping the pre-trained weights for these layers.

# %%
model_vgg.classifier = nn.Sequential(
            nn.Linear(25088, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 2))

# %%
model_vgg.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096)
#   (1): ReLU(inplace)
#   (2): Dropout(p=0.5)
#   (3): Linear(in_features=4096, out_features=4096)
#   (4): ReLU(inplace)
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=4096, out_features=2)
# )

# %% [markdown]
# Now make all the dense layers as learnable

# %%
for param in model_vgg.classifier.parameters():
    param.requires_grad = True

# %% [markdown]
# Shifting the model to gpu if available

# %%
if use_gpu:
    model_vgg = model_vgg.cuda()

# %% [markdown]
# Here we can see that only the last 6 layers are trainable

# %%
for param in model_vgg.parameters():
    print(param.requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ### Training

# %%
criterion = nn.CrossEntropyLoss()
lr_start = 0.001
optimizer = torch.optim.Adam(model_vgg.classifier.parameters(),lr = lr_start,weight_decay=1e-2)
num_epochs = 20

# %% [markdown]
# #### Training and evaluation

# %%
# %%time
train_loss_tracker = []
train_accuracy_tracker = []
val_loss_tracker = []
val_accuracy_tracker = []



for epoch in range(num_epochs):
    ## Training the model
    model_vgg.train(True) #Set model to training mode 
    print('------epoch{} started--------'.format(epoch))
    for i, (images, labels) in enumerate(train_loader, 0):
        images = Variable(images).cuda()  #for gpu
        labels = Variable(labels).cuda()  #for gpu

        # Forward + Backward + Optimize
        optimizer.zero_grad()
        outputs = model_vgg(images)
        loss = criterion(outputs, labels)
        train_loss_tracker.append(loss.data)
        loss.backward()
        optimizer.step()
        
        
        if (i + 1) % 5 == 0:
                avg_loss = np.mean(train_loss_tracker[-5:])
                print('Average training loss of last 5 mini-batches: %.4f' % (avg_loss))

    print('------epoch{} finished--------'.format(epoch))

    ## Prediction on training set for every epoch
    model_vgg.train(False)  #！！Set model to evaluation mode
    correct = 0
    total = 0
    for images, labels in train_loader:
        images = Variable(images).cuda()
        outputs = model_vgg(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted.cpu() == labels).sum()  #labels type is torch.totensor; predicted is torch.cuda.totensor
    train_acc = 100 * correct / total
    train_accuracy_tracker.append(train_acc)
    print('Accuracy on training images %.4f' % (train_acc))
    

    ## Prediction on validation set for every epoch
    correct = 0
    total = 0
    running_loss = 0.0
    n = 0
    for images, labels in valid_loader:
        images = Variable(images).cuda()
        labels_t = Variable(labels).cuda()
        outputs = model_vgg(images) #for gpu
        
        loss = criterion(outputs, labels_t)
        val_loss_tracker.append(loss.data)
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted.cpu() == labels).sum()
        images.cpu()
        labels_t.cpu()
    
    val_acc = 100 * correct / total
    val_accuracy_tracker.append(val_acc)
    val_loss_avg = np.mean(val_loss_tracker[-5:])
    
    print('Accuracy on validation images %.4f' % (val_acc))
    print('Average loss on validation images %.4f' % (val_loss_avg))

print('----Summary------')
print ('Best training accuracy: %.2f %%' % (max(train_accuracy_tracker))) 
print ('Best validation accuracy: %.2f %%' % (max(val_accuracy_tracker))) 
    
print('Finished Training')
# Out:
# ------epoch0 started--------
# Average training loss of last 5 mini-batches: 26.7915
# Average training loss of last 5 mini-batches: 1.1145
# ------epoch0 finished--------
# Accuracy on training images 80.7353
# Accuracy on validation images 71.6667
# Average loss on validation images 0.5954
# ------epoch1 started--------
# Average training loss of last 5 mini-batches: 0.6085
# Average training loss of last 5 mini-batches: 0.4848
# ------epoch1 finished--------
# Accuracy on training images 81.7647
# Accuracy on validation images 73.3333
# Average loss on validation images 0.5798
# ------epoch2 started--------
# Average training loss of last 5 mini-batches: 0.5004
# Average training loss of last 5 mini-batches: 0.3786
# ------epoch2 finished--------
# Accuracy on training images 87.9412
# Accuracy on validation images 80.8333
# Average loss on validation images 0.5084
# ------epoch3 started--------
# Average training loss of last 5 mini-batches: 0.3237
# Average training loss of last 5 mini-batches: 0.3417
# ------epoch3 finished--------
# Accuracy on training images 89.2647
# Accuracy on validation images 78.3333
# Average loss on validation images 0.4068
# ------epoch4 started--------
# Average training loss of last 5 mini-batches: 0.2999
# Average training loss of last 5 mini-batches: 0.2470
# ------epoch4 finished--------
# Accuracy on training images 92.6471
# Accuracy on validation images 82.5000
# Average loss on validation images 0.4145
# ------epoch5 started--------
# Average training loss of last 5 mini-batches: 0.2267
# Average training loss of last 5 mini-batches: 0.2198
# ------epoch5 finished--------
# Accuracy on training images 93.8235
# Accuracy on validation images 83.3333
# Average loss on validation images 0.4220
# ------epoch6 started--------
# Average training loss of last 5 mini-batches: 0.1685
# Average training loss of last 5 mini-batches: 0.2508
# ------epoch6 finished--------
# Accuracy on training images 96.0294
# Accuracy on validation images 86.6667
# Average loss on validation images 0.3440
# ------epoch7 started--------
# Average training loss of last 5 mini-batches: 0.1600
# Average training loss of last 5 mini-batches: 0.2338
# ------epoch7 finished--------
# Accuracy on training images 97.6471
# Accuracy on validation images 82.5000
# Average loss on validation images 0.3576
# ------epoch8 started--------
# Average training loss of last 5 mini-batches: 0.1251
# Average training loss of last 5 mini-batches: 0.1174
# ------epoch8 finished--------
# Accuracy on training images 97.6471
# Accuracy on validation images 85.8333
# Average loss on validation images 0.4203
# ------epoch9 started--------
# Average training loss of last 5 mini-batches: 0.0917
# Average training loss of last 5 mini-batches: 0.1503
# ------epoch9 finished--------
# Accuracy on training images 97.2059
# Accuracy on validation images 85.8333
# Average loss on validation images 0.4370
# ------epoch10 started--------
# Average training loss of last 5 mini-batches: 0.1840
# Average training loss of last 5 mini-batches: 0.1685
# ------epoch10 finished--------
# Accuracy on training images 97.3529
# Accuracy on validation images 84.1667
# Average loss on validation images 0.4973
# ------epoch11 started--------
# Average training loss of last 5 mini-batches: 0.1204
# Average training loss of last 5 mini-batches: 0.1556
# ------epoch11 finished--------
# Accuracy on training images 98.6765
# Accuracy on validation images 82.5000
# Average loss on validation images 0.4418
# ------epoch12 started--------
# Average training loss of last 5 mini-batches: 0.0807
# Average training loss of last 5 mini-batches: 0.1271
# ------epoch12 finished--------
# Accuracy on training images 97.9412
# Accuracy on validation images 83.3333
# Average loss on validation images 0.4675
# ------epoch13 started--------
# Average training loss of last 5 mini-batches: 0.0866
# Average training loss of last 5 mini-batches: 0.1040
# ------epoch13 finished--------
# Accuracy on training images 93.2353
# Accuracy on validation images 77.5000
# Average loss on validation images 0.6708
# ------epoch14 started--------
# Average training loss of last 5 mini-batches: 0.0970
# Average training loss of last 5 mini-batches: 0.1926
# ------epoch14 finished--------
# Accuracy on training images 97.5000
# Accuracy on validation images 80.0000
# Average loss on validation images 0.5379
# ------epoch15 started--------
# Average training loss of last 5 mini-batches: 0.1199
# Average training loss of last 5 mini-batches: 0.0938
# ------epoch15 finished--------
# Accuracy on training images 99.1176
# Accuracy on validation images 82.5000
# Average loss on validation images 0.4049
# ------epoch16 started--------
# Average training loss of last 5 mini-batches: 0.0591
# Average training loss of last 5 mini-batches: 0.0963
# ------epoch16 finished--------
# Accuracy on training images 99.7059
# Accuracy on validation images 82.5000
# Average loss on validation images 0.5293
# ------epoch17 started--------
# Average training loss of last 5 mini-batches: 0.0573
# Average training loss of last 5 mini-batches: 0.0702
# ------epoch17 finished--------
# Accuracy on training images 98.8235
# Accuracy on validation images 80.8333
# Average loss on validation images 0.6729
# ------epoch18 started--------
# Average training loss of last 5 mini-batches: 0.0789
# Average training loss of last 5 mini-batches: 0.0398
# ------epoch18 finished--------
# Accuracy on training images 96.1765
# Accuracy on validation images 80.8333
# Average loss on validation images 0.7062
# ------epoch19 started--------
# Average training loss of last 5 mini-batches: 0.1281
# Average training loss of last 5 mini-batches: 0.0649
# ------epoch19 finished--------
# Accuracy on training images 99.7059
# Accuracy on validation images 80.0000
# Average loss on validation images 0.5929
# ----Summary------
# Best training accuracy: 99.71 %
# Best validation accuracy: 86.67 %
# Finished Training
# CPU times: user 4min 33s, sys: 33.4 s, total: 5min 6s
# Wall time: 5min 49s

# %%
plt.plot(train_accuracy_tracker, label = 'train')
plt.plot(val_accuracy_tracker, label = 'valid')
plt.legend(loc = 'upper left')
plt.xlabel("number of epochs")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ### Precompute the activations

# %% [markdown]
# As we are only training part of the model, essentially only the last layer, we might as well precompute the activate and save it so that for each run of gradient descent we don't have to calculate the forward pass as till the last layer it'll be the same. For now we are precomputing the convolution block

# %%
def precompute(dataloader):
    conv_activations = []
    labels_list = []
    for i, (images, labels) in enumerate(dataloader):
        if use_gpu:
            images, labels = Variable(images.cuda()), Variable(
                labels.cuda())  #shifting to gpu

        activations = model_vgg.features(
            images)  #applying conv block on the batch of images

        #shifting to cpu and storing to numpy
        conv_activations.extend(activations.data.cpu().numpy())
        labels_list.extend(labels.data.cpu().numpy())

    #for all batches
    conv_activations = np.concatenate(
        [[activation] for activation in conv_activations])

    return (conv_activations, labels_list)

# %%
trn_pc_act,trn_lbl = precompute(train_loader) #precompute for train

# %%
trn_pc_act.shape #number of images x channels x height x width

# %%
len(trn_lbl)

# %%
val_pc_act,val_lbl = precompute(valid_loader) #precompute for valid

# %%
val_pc_act.shape #number of images x channels x height x width

# %%
len(val_lbl)

# %% [markdown]
# #### Data generator

# %%
np.random.permutation(10)

# %%
len(trn_pc_act)

# %%
def data_generator(conv_activations, labels, batch_size=64, shuffle=True):
#     set_trace()
    labels = np.array(labels)
    if shuffle:
        idx = np.random.permutation(len(conv_activations))
        conv_activations = conv_activations[idx]  #this will shuffle the features
        labels = labels[idx]  #follow the same indexing for the labels

    for i in range(0, len(conv_activations), batch_size):
        yield (conv_activations[i:i + batch_size], labels[i:i + batch_size])
